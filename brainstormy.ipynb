# %%
def genNumFilter(format, r = range(1,6)):
    return [format.format(num) for num in r]

# %%
import pandas as pd

data5 = pd.read_html('data/five.html')[0]

ftCols = genNumFilter('ft.of.{}', r=range(2,6))
data5[ftCols] = data5[ftCols].transform(lambda s: s.map(lambda x: int(x.replace(' ','').replace('Ft',''))))

data5
# Out:
#       year  week         date  num.of.5  ft.of.5  num.of.4  ft.of.4  num.of.3  \
# 0     2021    19  2021.05.15.         0        0        34  1432775      2122
# 1     2021    18  2021.05.08.         0        0        29  1636490      2479
# 2     2021    17  2021.05.01.         0        0        27  1607075      2055
# 3     2021    16  2021.04.24.         0        0        30  1533190      2360
# 4     2021    15  2021.04.17.         0        0        19  2482440      1467
# ...    ...   ...          ...       ...      ...       ...      ...       ...
# 3345  1957    14          NaN         0        0         0        0         0
# 3346  1957    13          NaN         0        0         0        0         0
# 3347  1957    12          NaN         0        0         0        0         0
# 3348  1957    11          NaN         0        0         0        0         0
# 3349  1957    10          NaN         0        0         0        0         0
#
#       ft.of.3  num.of.2  ft.of.2  num.1  num.2  num.3  num.4  num.5
# 0       24725     67639     2020     26     33     44     73     85
# 1       20675     74104     1795      3     28     62     76     90
# 2       22875     56021     2195     10     39     65     70     90
# 3       21185     72388     1795     13     17     34     50     61
# 4       35075     52450     2535     40     42     45     50     86
# ...       ...       ...      ...    ...    ...    ...    ...    ...
# 3345        0         0        0     26     33     38     47     53
# 3346        0         0        0      7      9     19     42     66
# 3347        0         0        0      8     12     24     26     85
# 3348        0         0        0      1     49     64     67     71
# 3349        0         0        0     16     61     71     77     89
#
# [3350 rows x 16 columns]

# %%
data5withWinnings = data5[data5.year > 1997]
data5withWinnings
keys = data5.keys()
winnerData = data5withWinnings[[key for key in keys][3:-5]]
winnerData
# Out:
#       num.of.5   ft.of.5  num.of.4  ft.of.4  num.of.3  ft.of.3  num.of.2  \
# 0            0         0        34  1432775      2122    24725     67639
# 1            0         0        29  1636490      2479    20675     74104
# 2            0         0        27  1607075      2055    22875     56021
# 3            0         0        30  1533190      2360    21185     72388
# 4            0         0        19  2482440      1467    35075     52450
# ...        ...       ...       ...      ...       ...      ...       ...
# 1215         0         0        29   654420      3716     5107    103185
# 1216         1  48395636        88   220718      5913     3285    133772
# 1217         0         0        58   332643      3456     5583     93153
# 1218         1  47708148        14  1392092      1606    12135     59881
# 1219         0         0        69   270685      5090     3669    124921
#
#       ft.of.2
# 0        2020
# 1        1795
# 2        2195
# 3        1795
# 4        2535
# ...       ...
# 1215      322
# 1216      254
# 1217      362
# 1218      570
# 1219      262
#
# [1220 rows x 8 columns]

# %%
winnerData.describe()
# Out:
#           num.of.5       ft.of.5     num.of.4       ft.of.4      num.of.3  \
# count  1220.000000  1.220000e+03  1220.000000  1.220000e+03   1220.000000
# mean      0.104098  9.538442e+07    44.377049  1.619514e+06   3740.690984
# std       0.359769  4.693544e+08    31.316828  1.033800e+06   1839.976095
# min       0.000000  0.000000e+00     3.000000  1.543780e+05   1131.000000
# 25%       0.000000  0.000000e+00    24.000000  9.293062e+05   2512.750000
# 50%       0.000000  0.000000e+00    37.000000  1.365440e+06   3281.500000
# 75%       0.000000  0.000000e+00    55.000000  2.084762e+06   4403.750000
# max       4.000000  6.431516e+09   291.000000  8.673023e+06  17104.000000
#
#             ft.of.3       num.of.2      ft.of.2
# count   1220.000000    1220.000000  1220.000000
# mean   16870.607377  103634.732787  1158.437705
# std     7089.936937   41944.894159   457.450184
# min     2741.000000   46062.000000   235.000000
# 25%    11629.500000   76907.750000   795.000000
# 50%    16043.000000   94141.000000  1142.500000
# 75%    21162.500000  118145.250000  1455.000000
# max    44265.000000  432506.000000  2865.000000

# %%
cols = genNumFilter('num.{}') # [f'num.{ber}' for ber in range(1,6)]
# print(cols)
numbers = data5[cols]
numbers
# Out:
#       num.1  num.2  num.3  num.4  num.5
# 0        26     33     44     73     85
# 1         3     28     62     76     90
# 2        10     39     65     70     90
# 3        13     17     34     50     61
# 4        40     42     45     50     86
# ...     ...    ...    ...    ...    ...
# 3345     26     33     38     47     53
# 3346      7      9     19     42     66
# 3347      8     12     24     26     85
# 3348      1     49     64     67     71
# 3349     16     61     71     77     89
#
# [3350 rows x 5 columns]

# %%
numbers.describe()
# Out:
#              num.1        num.2        num.3        num.4        num.5
# count  3350.000000  3350.000000  3350.000000  3350.000000  3350.000000
# mean     14.978806    29.826269    45.579403    60.519403    75.455522
# std      12.257605    15.653257    16.475761    15.710336    12.442509
# min       1.000000     2.000000     5.000000     8.000000    24.000000
# 25%       5.000000    18.000000    33.000000    50.000000    69.000000
# 50%      12.000000    28.000000    46.000000    62.000000    79.000000
# 75%      22.000000    41.000000    58.000000    73.000000    85.000000
# max      65.000000    82.000000    85.000000    89.000000    90.000000

# %%
from matplotlib import pyplot

xs = [[x,x,x,x,x] for x in range(0,len(numbers))]
xs = [x for sublist in xs for x in sublist]
xsrev = [len(numbers)-x for x in xs]
xsneg = [-x for x in xs]

ys = [item[1] for item in numbers.iterrows()]
ys = [y for sublist in ys for y in sublist]

pyplot.rcParams['figure.figsize'] = (50,10)
pyplot.scatter(xsrev, ys)
